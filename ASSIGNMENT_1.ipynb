# %%
import numpy as np
import pandas as pd
data={
    "Randam_value1":np.random.randint(10,100,4),
    "Randam_value2":np.random.randint(10,100,4),
    "Randam_value3":np.random.randint(10,100,4),
    "Randam_value4":np.random.randint(10,100,4)
}
df=pd.DataFrame(data)
df
# Out:
#    Randam_value1  Randam_value2  Randam_value3  Randam_value4
# 0             61             76             37             40
# 1             70             31             37             67
# 2             76             85             84             44
# 3             27             49             49             57

# %%
df.describe()
# Out:
#        Randam_value1  Randam_value2  Randam_value3  Randam_value4
# count       4.000000       4.000000       4.000000       4.000000
# mean       58.500000      60.250000      51.750000      52.000000
# std        21.886069      24.784067      22.231734      12.355835
# min        27.000000      31.000000      37.000000      40.000000
# 25%        52.500000      44.500000      37.000000      43.000000
# 50%        65.500000      62.500000      43.000000      50.500000
# 75%        71.500000      78.250000      57.750000      59.500000
# max        76.000000      85.000000      84.000000      67.000000

# %%
df.isnull().sum()
# Out:
# Randam_value1    0
# Randam_value2    0
# Randam_value3    0
# Randam_value4    0
# dtype: int64

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Randam_value1  4 non-null      int64
#  1   Randam_value2  4 non-null      int64
#  2   Randam_value3  4 non-null      int64
#  3   Randam_value4  4 non-null      int64
# dtypes: int64(4)
# memory usage: 256.0 bytes

# %%
df.loc[:,['Randam_value2','Randam_value3']]
# Out:
#    Randam_value2  Randam_value3
# 0             76             37
# 1             31             37
# 2             85             84
# 3             49             49

# %%
df.iloc[:,[1,2]]
# Out:
#    Randam_value2  Randam_value3
# 0             76             37
# 1             31             37
# 2             85             84
# 3             49             49
